# %%
import random

username = "shikhar"
pin = 177013

attempts = 3

while attempts > 0:
    print("----- ATM LOGIN -----")

    user = input("Enter Username: ").lower()
    user_pin = int(input("Enter PIN: "))

    chars = "abcdefghijklmnopqrstuvwxyz0123456789"
    captcha = ""

    for i in range(6):
        captcha = captcha + random.choice(chars)

    print("CAPTCHA:", captcha)
    user_captcha = input("Enter CAPTCHA: ")

    if user == username and user_pin == pin and user_captcha == captcha:
        print("Login Successful!\n")

        balance = 5000

        while True:
            print("\n1. Balance")
            print("2. Withdraw")
            print("3. Deposit")
            print("4. Exit")

            choice = int(input("Enter your choice: "))

            if choice == 1:
                print("Balance =", balance)

            elif choice == 2:
                amount = int(input("Enter amount to withdraw: "))
                if amount <= balance:
                    balance = balance - amount
                    print("Withdrawal Successful")
                else:
                    print("Insufficient Balance")

            elif choice == 3:
                amount = int(input("Enter amount to deposit: "))
                balance = balance + amount
                print("Deposit Successful")

            elif choice == 4:
                print("Thank You!")
                break

            else:
                print("Invalid Choice")
        break

    else:
        attempts = attempts - 1
        if attempts > 0:
            print("Invalid Username, PIN, or CAPTCHA")
            print("Attempts left:", attempts)
        else:
            print("Account Locked! Too many incorrect attempts.")
# Out:
# ----- ATM LOGIN -----
# CAPTCHA: x44kc4
# Login Successful!
#
#
# 1. Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Balance = 5000
#
# 1. Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Deposit Successful
#
# 1. Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Withdrawal Successful
#
# 1. Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Balance = 24000
#
# 1. Balance
# 2. Withdraw
# 3. Deposit
# 4. Exit
# Thank You!
